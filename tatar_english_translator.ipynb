# %% [markdown]
# <a href="https://colab.research.google.com/github/akhmetvaleev-ruslan/lstm-generation-example/blob/main/tatar_english_translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
# Turn a Unicode string to plain ASCII, thanks to
# http://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )
# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    return s

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open('%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    pairs = [[pair[0], pair[1]] for pair in pairs]
    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
MAX_LENGTH = 20
eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH #and \
        #p[1].startswith(eng_prefixes)

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

input_lang, output_lang, pairs = prepareData('eng', 'tat', True)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 667 sentence pairs
# Trimmed to 665 sentence pairs
# Counting words...
# Counted words:
# tat 1266
# eng 799
# ['урыныңны җәи .', 'make your bed .']

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0.5

def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]
        #print(input_tensor)
        #print(target_tensor)
        
        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []

        for di in range(max_length):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words

# %%
from evaluate import load
#Метрика качества на основе n-грамм
bleu = load("bleu")

predictions = ["the picture the picture by me", "the picture the picture by me"]
references = ["the picture is clicked by me", "this picture was clicked by me"]

print(bleu.compute(predictions=predictions, references=references))

def evaluateRandomly(encoder, decoder, n=100):
    b = 0
    for i in range(n):
        c = 0
        pair = random.choice(pairs)
        
        output_words = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        
        pred = output_sentence
        ref = pair[1]
        bleu_i = bleu.compute(predictions=[pred], references=[ref])
        
        if bleu_i['precisions'][0] < 1:
            print('>', pair[0])
            print('=', pair[1])
            print('<', output_sentence)
            print('')
        
        b += bleu_i['precisions'][0] / n
    b *= 100
    print(float('{:.3f}'.format(b)))
# Out:
# {'bleu': 0.0, 'precisions': [0.5833333333333334, 0.3, 0.0, 0.0], 'brevity_penalty': 1.0, 'length_ratio': 1.0, 'translation_length': 12, 'reference_length': 12}

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder1 = DecoderRNN(hidden_size, output_lang.n_words).to(device)

trainIters(encoder1, decoder1, 75000, print_every=5000)
# Out:
# 2m 4s (- 28m 56s) (5000 6%) 3.3052
# 4m 3s (- 26m 22s) (10000 13%) 1.4025
# 6m 6s (- 24m 27s) (15000 20%) 0.3491
# 8m 8s (- 22m 24s) (20000 26%) 0.1448
# 10m 14s (- 20m 28s) (25000 33%) 0.1098
# 12m 26s (- 18m 39s) (30000 40%) 0.1255
# 14m 30s (- 16m 35s) (35000 46%) 0.1103
# 16m 33s (- 14m 29s) (40000 53%) 0.0968
# 18m 37s (- 12m 25s) (45000 60%) 0.1020
# 20m 38s (- 10m 19s) (50000 66%) 0.0937
# 22m 41s (- 8m 15s) (55000 73%) 0.0837
# 24m 43s (- 6m 10s) (60000 80%) 0.0918
# 26m 47s (- 4m 7s) (65000 86%) 0.0893
# 28m 50s (- 2m 3s) (70000 93%) 0.0950
# 30m 53s (- 0m 0s) (75000 100%) 0.0840

# %%
evaluateRandomly(encoder1, decoder1)
# Out:
# > сак бул ! биредә зур чокыр бар .
# = watch out ! there's a big hole there .
# < watch out ! there's a big hole there . <EOS>
#
# > син кем һәм каидан килдең ?
# = who are you and where do you come from ?
# < who are you and where do you come from ? <EOS>
#
# > томнан сорагыз .
# = ask tom .
# < ask tom . <EOS>
#
# > алма ашадым .
# = i ate apples .
# < i ate apples . <EOS>
#
# > qaycan ocrasabiz ?
# = what time are we meeting ?
# < what time are we meeting ? <EOS>
#
# > том өенә юл буе чаба-чаба каитты .
# = tom ran all the way home .
# < tom ran all the way home . <EOS>
#
# > инглизчә сөиләшәсезме ?
# = do you speak english ?
# < do you speak english ? <EOS>
#
# > томны сораштырып карагыз .
# = ask tom .
# < ask tom . <EOS>
#
# > бостонда дымлы бүген .
# = boston is humid today .
# < boston is humid today . <EOS>
#
# > кергәләп иөрегез .
# = come and see us more often .
# < come and see us more often . <EOS>
#
# > хата ясаудан курыкма .
# = don't be afraid of making mistakes .
# < don't be afraid of making mistakes . <EOS>
#
# > шулаимы ?
# = really ?
# < really ? <EOS>
#
# > lakin xazer, alege tacribane iska alganda, uzemnen kup narsalarga oyranganemne anlıym .
# = and now, looking back on the experience, i really learned a lot .
# < and now, looking back on the experience, i really learned a lot . <EOS>
#
# > бүлмәдә кем дә булса бармы ?
# = is there anyone in the room ?
# < is there anyone in the room ? <EOS>
#
# > өстәрлек тагын башка нәрсә юк .
# = there isn't much more to add .
# < there isn't much more to add . <EOS>
#
# > без беркаичан да кафе-рестораннарда ашамыибыз диярлек .
# = we almost never eat out .
# < we almost never eat out . <EOS>
#
# > том үлгән дип уиладым .
# = i thought tom was dead .
# < i thought tom was dead . <EOS>
#
# > томны эш бүлмәсендә үлгән килеш таптылар .
# = tom was found dead in his study .
# < tom was found dead in his study . <EOS>
#
# > min, bireda yaxsı xezmat kursatalar ham rizıqları da tamle, dip isetkan idem .
# = i hear the service there is good and the food is delicious .
# < i hear the service there is good and the food is delicious . <EOS>
#
# > сәгать унике тулды .
# = the clock struck twelve .
# < the clock struck twelve . <EOS>
#
# > барысы да әибәт .
# = everything is ok .
# < everything is fine . <EOS>
#
# > ул бәхетле .
# = she is happy .
# < he is happy . <EOS>
#
# > зәңгәр төс сиңа килешә .
# = blue looks good on you .
# < blue looks good on you . <EOS>
#
# > ул авырыи .
# = he is sick .
# < he is ill . <EOS>
#
# > барысы да әибәт .
# = everything is fine .
# < everything is fine . <EOS>
#
# > том күп акча тапты .
# = tom found a lot of money .
# < tom found a lot of money . <EOS>
#
# > ул өидә юк .
# = he's not at home .
# < he's not at home . <EOS>
#
# > томның үлеме кеше үтерү нәтиҗәсе дип бәяләнде .
# = tom's death was ruled a homicide .
# < tom's death was ruled a homicide . <EOS>
#
# > һичшиксез .
# = there's no doubt about it .
# < there's no doubt about it . <EOS>
#
# > бу бик борынгы китап .
# = that book is very old .
# < that book is very old . <EOS>
#
# > әниеңне яратасыңмы ?
# = do you love your mother ?
# < do you love your mother ? <EOS>
#
# > каичан керешәбез ?
# = when do we start ?
# < when do we start ? <EOS>
#
# > аның исемен оныттым .
# = i forgot his name .
# < i forgot his name . <EOS>
#
# > бу — эт .
# = this is a dog .
# < this is a dog . <EOS>
#
# > күземә кара .
# = look into my eyes .
# < look into my eyes . <EOS>
#
# > аның өч кызы бар .
# = he has three daughters .
# < he has three daughters . <EOS>
#
# > бурычка биргән акчаларымны каичан каитарырга җыенасың ?
# = when are you going to pay me back the money i lent you ?
# < when are you going to pay me back the money i lent you ? <EOS>
#
# > ашыксаң өлгерәсең әле автобуска .
# = if you hurry, you'll catch the bus .
# < if you hurry, you'll catch the bus . <EOS>
#
# > чәчемне юмадым .
# = i haven't washed my hair .
# < i haven't washed my hair . <EOS>
#
# > инглиз телен аңлыисызмы ?
# = do you understand english ?
# < do you understand english ? <EOS>
#
# > син яхшы музыкант .
# = you're a good musician .
# < you're a good musician . <EOS>
#
# > синең җавап дөрес .
# = your answer is right .
# < your answer is right . <EOS>
#
# > bu minem ocen bik qaderle .
# = i really appreciate it .
# < i really appreciate it . <EOS>
#
# > син чибәр .
# = you're pretty .
# < you are beautiful . <EOS>
#
# > укыисың килмәсә, укыма .
# = if you don't want to read, then don't .
# < if you don't want to read, then don't . <EOS>
#
# > этем турында каигыртма .
# = don't worry about my dog .
# < don't worry about my dog . <EOS>
#
# > яңгыр ява башлады .
# = it started to rain .
# < it started to rain . <EOS>
#
# > аның абыисы - данлыклы футболчы .
# = his brother is a famous soccer player .
# < his brother is a famous soccer player . <EOS>
#
# > бүген көн әибәт .
# = the weather is nice today .
# < the weather is nice today . <EOS>
#
# > белми идеңме ?
# = didn't you know that ?
# < didn't you know that ? <EOS>
#
# > бүген кар ява .
# = it's snowing today .
# < it's snowing today . <EOS>
#
# > миңа буяу кирәк .
# = i need paint .
# < i need paint . <EOS>
#
# > каичан теләсәң шунда кил .
# = come anytime .
# < come anytime . <EOS>
#
# > минем китапларым күп .
# = i have a lot of books .
# < i have a lot of books . <EOS>
#
# > мин сине эзлим .
# = i'm looking for you .
# < i'm looking for you . <EOS>
#
# > мин мәктәпкә барырга теләмим .
# = i don't want to go to school .
# < i don't want to go to school . <EOS>
#
# > син чибәр .
# = you are beautiful .
# < you are beautiful . <EOS>
#
# > ачыкларга мөмкинлек бирсәң иде .
# = please give me a chance to explain .
# < please give me a chance to explain . <EOS>
#
# > бу минем өчен күп нәрсәне аңлата .
# = this means a lot to me .
# < this means a lot to me . <EOS>
#
# > ашыисым килми .
# = i'm not hungry .
# < i'm not hungry . <EOS>
#
# > иөзәргә каичан өирәндең ?
# = when did you learn to swim ?
# < when did you learn to swim ? <EOS>
#
# > ул яхшы кеше .
# = he's a good person .
# < he's a good person . <EOS>
#
# > тылмачыгыз бармы ?
# = do you have an interpreter ?
# < do you have an interpreter ? <EOS>
#
# > полиция фикеренчә, беркем дә зыян күрмәгән .
# = according to the police, no one was injured .
# < according to the police, no one was injured . <EOS>
#
# > декабрьдә 31 көн .
# = there are 31 days in december .
# < december has thirty-one days . <EOS>
#
# > полиция фикеренчә, беркем дә зыян күрмәгән .
# = according to the police, no one was injured .
# < according to the police, no one was injured . <EOS>
#
# > каләмнең карасы беткән .
# = the pen has run out of ink .
# < the pen has run out of ink . <EOS>
#
# > озакламыи дәрес яңадан башлана .
# = classes are starting again soon .
# < classes are starting again soon . <EOS>
#
# > син минем дустым .
# = you are my friend .
# < you are my friend . <EOS>
#
# > сез моны көненә ничә мәртәбә эшлисез ?
# = how many times a day do you do that ?
# < how many times a day do you do that ? <EOS>
#
# > бу юлы миңа бәхет елмаиды .
# = i was happy there .
# < i was happy there . <EOS>
#
# > бүген шәһәргә барасыңмы ?
# = are you going to town today ?
# < are you going to town today ? <EOS>
#
# > мин сине эзлим .
# = i'm looking for you .
# < i'm looking for you . <EOS>
#
# > аның өч баласы бар .
# = he has three children .
# < he has three children . <EOS>
#
# > буш вакытыгыз күпме ?
# = do you have a lot of free time ?
# < do you have a lot of free time ? <EOS>
#
# > мин беркемгә бернинди сүз бирмәдем .
# = i didn't promise anybody anything .
# < i didn't promise anybody anything . <EOS>
#
# > хәлләрегез ничек ?
# = how are you ?
# < how are you ? <EOS>
#
# > эш бетте .
# = the party's over .
# < the party's over . <EOS>
#
# > demokratia, sınap qaralgan basqa idara alımnarın sanamasan, in nacarı .
# = democracy is the worst form of government, except all the others that have been tried .
# < democracy is the worst form of government, except all the others that have been tried . <EOS>
#
# > миңа анда барырга кирәк .
# = i have to go there .
# < i have to go there . <EOS>
#
# > мин инде томга кул селтәдем .
# = i gave up on tom .
# < i gave up on tom . <EOS>
#
# > waqıtın togalrak bilgelise ide .
# = i'm not sure about the date .
# < i'm not sure about the date . <EOS>
#
# > өстәрлек тагын башка нәрсә юк .
# = there isn't much more to add .
# < there isn't much more to add . <EOS>
#
# > томны кулга алдылар .
# = tom was arrested .
# < tom was arrested . <EOS>
#
# > беркем дә бу проблеманы чишә алмыи .
# = nobody can solve this problem .
# < nobody can solve this problem . <EOS>
#
# > нәрсәне күбрәк ошатасың ?
# = what do you prefer ?
# < what do you prefer ? <EOS>
#
# > алтын тимердән авыррак .
# = gold is heavier than iron .
# < gold is heavier than iron . <EOS>
#
# > су азаиды .
# = water has become scarce .
# < water has become scarce . <EOS>
#
# > нигә син моны сорыисың ?
# = why are you asking about that ?
# < why are you asking about that ? <EOS>
#
# > ни яздың ?
# = what did you write ?
# < what did you write ? <EOS>
#
# > мин австралиядан .
# = i come from australia .
# < i come from australia . <EOS>
#
# > кулларымны юып алыиммы ?
# = can i wash my hands ?
# < can i wash my hands ? <EOS>
#
# > min, bireda yaxsı xezmat kursatalar ham rizıqları da tamle, dip isetkan idem .
# = i hear the service there is good and the food is delicious .
# < i hear the service there is good and the food is delicious . <EOS>
#
# > том, миңа комачауламауларын телим, диде .
# = tom said that he didn't want to be disturbed .
# < tom said that he didn't want to be disturbed . <EOS>
#
# > безнең белән уинарга телисеңме ?
# = would you like to play with us ?
# < would you like to play with us ? <EOS>
#
# > мария әнисенә ярдәм итә .
# = mary is helping her mother .
# < mary is helping her mother . <EOS>
#
# > сәгатем каида ?
# = where's my watch ?
# < where is my clock ? <EOS>
#
# > әтиең белән кил .
# = come with your father .
# < come with your father . <EOS>
#
# > мин яшеренмим дә .
# = i'm not hiding .
# < i'm not hiding . <EOS>
#
# > аралашу өчен уңаисызрак вакытмы ?
# = is this a bad time to chat ?
# < is this a bad time to chat ? <EOS>
#
# 64.473
